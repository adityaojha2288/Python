# %%
import pandas as pd
cars_sale=pd.read_csv('car-sales.csv')
cars_sale
# importing data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ##EXporting car sales
# cars_sale.to_csv("exported car sales")z

# %%
cars = pd.read_csv("exported car sales")
cars
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# to solve this

# %%
cars_sale.to_csv("exported car sales", index = False)
#now

# %%
cars = pd.read_csv("exported car sales")
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describing Data

# %%
cars_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
cars_sale.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# to make the columns list we can do this
cars_columns = cars_sale.columns
cars_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cars_sale.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
cars_sale.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
## Remember describe olny works on numeric values as it is shown above

# %%
cars_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
cars_sale.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
## in sum all is added and we can also use other function such as mean,median,max,min
## we can also use specific coloumn by typing the columns as string

# %%
cars_sale['Doors'].sum()
# Out:
# 40

# %%
len(cars_sale) ## to see how many rows dataset contin as sometimes we only need a sample not population
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
cars_sale.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
## .head() function helps us select the amount of row we needed to see what type of data the csv contain and 
## also helps in selecting data
# and to select the data from bottom .tail() is used.

# %%
##loc and iloc
animals = pd.Series(['Panda','Tiger','dog','cat','snake'])
animals
# Out:
# 0    Panda
# 1    Tiger
# 2      dog
# 3      cat
# 4    snake
# dtype: object

# %%
animals = pd.Series(['Panda','Tiger','dog','cat','snake'],index = [0,3,8,5,3])
animals
# Out:
# 0    Panda
# 3    Tiger
# 8      dog
# 5      cat
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3    Tiger
# 3    snake
# dtype: object

# %%
## loc mere means location as we have pou 3 in there,we got all the values that have index 3 or that have assigned index
# if we want the car at 0th index then we have to put 0
## lets try with car sales

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cars_sale.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#iloc
animals.iloc[3]
# Out:
# 'cat'

# %%
cars_sale.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
## iloc = position and loc = assigned index

# %%
# to bring the data from start to specific position
cars_sale.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
cars_sale.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
# thats the difference

# %% [markdown]
# # Filtering Data

# %%
cars_sale[cars_sale['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
cars_sale[cars_sale['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
## we can cross the main table
pd.crosstab(cars_sale.Make,cars_sale.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#group by
cars_sale.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
cars_sale['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
# converting object data type to int
cars_sale['Price'] = cars_sale['Price'].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\ADITY\AppData\Local\Temp/ipykernel_15160/1541875576.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   cars_sale['Price'] = cars_sale['Price'].str.replace('[\$\,\.]','').astype(int)

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
cars_sale.Price = cars_sale.Price /10
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
cars_sales_missing = pd.read_csv('car-sales-missing-data.csv')
cars_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# to fill nan with value we can use .fillna

# %%
#to remove the nan for the data set we can use
cars_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# to save the code progress without defining or reassinging it we can use inplace
# as default inplace is always false but by changing it to true we can do the change without reassigning it

# %%
cars_sales_missing.dropna(inplace = True)

# %%
cars_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
#new column can be created 
cars_sale['Seats'] = pd.Series([5,5,5,5,5])

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
cars_sale.fillna(5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
#we can also make a column from the list but the list should have elements for each column
economy = [7.5,8,9.2,6,5,7.7,8,7.6,8.1,8.5]
cars_sale["Economy per 100KM"]= economy

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy  \
# 0  Toyota  White         150043      4   4000.0    5.0      7.5
# 1   Honda    Red          87899      4   5000.0    5.0      8.0
# 2  Toyota   Blue          32549      3   7000.0    5.0      9.2
# 3     BMW  Black          11179      5  22000.0    5.0      6.0
# 4  Nissan  White         213095      4   3500.0    5.0      5.0
# 5  Toyota  Green          99213      4   4500.0    NaN      7.7
# 6   Honda   Blue          45698      4   7500.0    NaN      8.0
# 7   Honda   Blue          54738      4   7000.0    NaN      7.6
# 8  Toyota  White          60000      4   6250.0    NaN      8.1
# 9  Nissan  White          31600      4   9700.0    NaN      8.5
#
#    Economy per 100KM
# 0                7.5
# 1                8.0
# 2                9.2
# 3                6.0
# 4                5.0
# 5                7.7
# 6                8.0
# 7                7.6
# 8                8.1
# 9                8.5

# %%
cars_sale = cars_sale.drop('Economy', axis = 1)
#axis = 0 means row and axis =1 means columns

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                8.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                9.2
# 3     BMW  Black          11179      5  22000.0    5.0                6.0
# 4  Nissan  White         213095      4   3500.0    5.0                5.0
# 5  Toyota  Green          99213      4   4500.0    NaN                7.7
# 6   Honda   Blue          45698      4   7500.0    NaN                8.0
# 7   Honda   Blue          54738      4   7000.0    NaN                7.6
# 8  Toyota  White          60000      4   6250.0    NaN                8.1
# 9  Nissan  White          31600      4   9700.0    NaN                8.5

# %%
# if we have to insert a certain value in data frame and all the values are same then we can use this
cars_sale['Wheels'] =4
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                8.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                9.2
# 3     BMW  Black          11179      5  22000.0    5.0                6.0
# 4  Nissan  White         213095      4   3500.0    5.0                5.0
# 5  Toyota  Green          99213      4   4500.0    NaN                7.7
# 6   Honda   Blue          45698      4   7500.0    NaN                8.0
# 7   Honda   Blue          54738      4   7000.0    NaN                7.6
# 8  Toyota  White          60000      4   6250.0    NaN                8.1
# 9  Nissan  White          31600      4   9700.0    NaN                8.5
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
cars_sale['Seats'].fillna(5,inplace = True)

# %%
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                8.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                9.2
# 3     BMW  Black          11179      5  22000.0    5.0                6.0
# 4  Nissan  White         213095      4   3500.0    5.0                5.0
# 5  Toyota  Green          99213      4   4500.0    5.0                7.7
# 6   Honda   Blue          45698      4   7500.0    5.0                8.0
# 7   Honda   Blue          54738      4   7000.0    5.0                7.6
# 8  Toyota  White          60000      4   6250.0    5.0                8.1
# 9  Nissan  White          31600      4   9700.0    5.0                8.5
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
## to take a sample from the data we can use
car_sales_shuffeled=cars_sale.sample(frac=1)
# 0.5 is the percent of data we needed and it is shuffeled

# %%
car_sales_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM  \
# 1   Honda    Red           True      4   5000.0    5.0                8.0
# 3     BMW  Black           True      5  22000.0    5.0                6.0
# 7   Honda   Blue           True      4   7000.0    5.0                7.6
# 6   Honda   Blue           True      4   7500.0    5.0                8.0
# 5  Toyota  Green           True      4   4500.0    5.0                7.7
# 9  Nissan  White           True      4   9700.0    5.0                8.5
# 4  Nissan  White           True      4   3500.0    5.0                5.0
# 8  Toyota  White           True      4   6250.0    5.0                8.1
# 0  Toyota  White           True      4   4000.0    5.0                7.5
# 2  Toyota   Blue           True      3   7000.0    5.0                9.2
#
#    Wheels
# 1       4
# 3       4
# 7       4
# 6       4
# 5       4
# 9       4
# 4       4
# 8       4
# 0       4
# 2       4

# %%
car_sales_shuffeled.reset_index(drop=True,inplace=True)
car_sales_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Economy per 100KM  \
# 0   Honda   Blue          45698      4  7500.0    5.0                8.0
# 1   Honda    Red          87899      4  5000.0    5.0                8.0
# 2  Toyota  Green          99213      4  4500.0    5.0                7.7
# 3   Honda   Blue          54738      4  7000.0    5.0                7.6
# 4  Toyota  White         150043      4  4000.0    5.0                7.5
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4

# %%
# Reset index will reset the index of the shuffeled data and drop will drop the old index 
#if drop isnt used then we have a new index column and the shuffeled index column
cars_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                8.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                9.2
# 3     BMW  Black          11179      5  22000.0    5.0                6.0
# 4  Nissan  White         213095      4   3500.0    5.0                5.0
# 5  Toyota  Green          99213      4   4500.0    5.0                7.7
# 6   Honda   Blue          45698      4   7500.0    5.0                8.0
# 7   Honda   Blue          54738      4   7000.0    5.0                7.6
# 8  Toyota  White          60000      4   6250.0    5.0                8.1
# 9  Nissan  White          31600      4   9700.0    5.0                8.5
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
cars_sale['Odometer (KM)'] = cars_sale['Odometer (KM)'].apply(lambda x: x/1.6)
## little messed up but this is how you can also apply the lambda function if you have to have any conversions

# %%
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Economy per 100KM  \
# 0  Toyota  White          0.625      4   4000.0    5.0                7.5
# 1   Honda    Red          0.625      4   5000.0    5.0                8.0
# 2  Toyota   Blue          0.625      3   7000.0    5.0                9.2
# 3     BMW  Black          0.625      5  22000.0    5.0                6.0
# 4  Nissan  White          0.625      4   3500.0    5.0                5.0
# 5  Toyota  Green          0.625      4   4500.0    5.0                7.7
# 6   Honda   Blue          0.625      4   7500.0    5.0                8.0
# 7   Honda   Blue          0.625      4   7000.0    5.0                7.6
# 8  Toyota  White          0.625      4   6250.0    5.0                8.1
# 9  Nissan  White          0.625      4   9700.0    5.0                8.5
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4
